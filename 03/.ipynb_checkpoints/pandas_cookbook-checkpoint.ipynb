# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods = 6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index = dates, columns = list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.<TAB>  # noqa: E225, E999
df2.A                  df2.bool
df2.abs                df2.boxplot
df2.add                df2.C
df2.add_prefix         df2.clip
df2.add_suffix         df2.clip_lower
df2.align              df2.clip_upper
df2.all                df2.columns
df2.any                df2.combine
df2.append             df2.combine_first
df2.apply              df2.compound
df2.applymap           df2.consolidate
df2.D
# Out:
#   File "<ipython-input-16-c46c68fb4819>", line 1
#     df2.<TAB>  # noqa: E225, E999
#         ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d1ec329ba876> in <module>()
# ----> 1 df.to_numpy()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numpy'

# %%
df2.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a6f966096c1a> in <module>()
# ----> 1 df2.to_numpy()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numpy'

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.366574 -0.378572  0.389377  0.256226
# std    0.997458  0.853852  0.917792  1.312673
# min   -1.935550 -1.326783 -0.876755 -1.859209
# 25%   -0.931256 -1.001298 -0.100685 -0.447618
# 50%   -0.112534 -0.403455  0.513023  0.806535
# 75%    0.337637 -0.069136  0.641865  1.186025
# max    0.677641  1.020537  1.807413  1.336644

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.677641    0.386881   -0.414971   -1.935550   -1.103351    0.189904
# B   -0.516797   -0.290112   -1.326783    1.020537   -1.162799    0.004523
# C    1.807413   -0.876755    0.516989    0.683490    0.509058   -0.303933
# D    1.310926   -1.859209    0.801747    1.336644   -0.864073    0.811323

# %%
df.sort_index(axis = 1 ,ascending = True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323

# %%
df.sort_index(axis = 1 ,ascending = False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.310926  1.807413 -0.516797  0.677641
# 2013-01-02 -1.859209 -0.876755 -0.290112  0.386881
# 2013-01-03  0.801747  0.516989 -1.326783 -0.414971
# 2013-01-04  1.336644  0.683490  1.020537 -1.935550
# 2013-01-05 -0.864073  0.509058 -1.162799 -1.103351
# 2013-01-06  0.811323 -0.303933  0.004523  0.189904

# %%
df.sort_values(by = 'B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644

# %%
df['A']
# Out:
# 2013-01-01    0.677641
# 2013-01-02    0.386881
# 2013-01-03   -0.414971
# 2013-01-04   -1.935550
# 2013-01-05   -1.103351
# 2013-01-06    0.189904
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747

# %%
df['20130102':'20130103']
# Out:
#                    A         B         C         D
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747

# %%
df.loc[dates[0]]
# Out:
# A    0.677641
# B   -0.516797
# C    1.807413
# D    1.310926
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[: , ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01  0.677641 -0.516797
# 2013-01-02  0.386881 -0.290112
# 2013-01-03 -0.414971 -1.326783
# 2013-01-04 -1.935550  1.020537
# 2013-01-05 -1.103351 -1.162799
# 2013-01-06  0.189904  0.004523

# %%
df.loc['20130102':'20130104', ['A','B']]
# Out:
#                    A         B
# 2013-01-02  0.386881 -0.290112
# 2013-01-03 -0.414971 -1.326783
# 2013-01-04 -1.935550  1.020537

# %%
df.loc['20130102', ['A','B']]
# Out:
# A    0.386881
# B   -0.290112
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# 0.677640560750245

# %%
df.at[dates[0],'A']
# Out:
# 0.677640560750245

# %%
df.iloc[3]
# Out:
# A   -1.935550
# B    1.020537
# C    0.683490
# D    1.336644
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.935550  1.020537
# 2013-01-05 -1.103351 -1.162799

# %%
df.iloc[1,1]
# Out:
# -0.2901122654444268

# %%
df.iat[1,1]
# Out:
# -0.2901122654444268

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.677641       NaN  1.807413  1.310926
# 2013-01-02  0.386881       NaN       NaN       NaN
# 2013-01-03       NaN       NaN  0.516989  0.801747
# 2013-01-04       NaN  1.020537  0.683490  1.336644
# 2013-01-05       NaN       NaN  0.509058       NaN
# 2013-01-06  0.189904  0.004523       NaN  0.811323

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.677641 -0.516797  1.807413  1.310926    one
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209    one
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747    two
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644  three
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073   four
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747   two
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073  four

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods = 6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0],'A'] = 0
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000 -0.516797  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323

# %%
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000  0.000000  1.807413  1.310926
# 2013-01-02  0.386881 -0.290112 -0.876755 -1.859209
# 2013-01-03 -0.414971 -1.326783  0.516989  0.801747
# 2013-01-04 -1.935550  1.020537  0.683490  1.336644
# 2013-01-05 -1.103351 -1.162799  0.509058 -0.864073
# 2013-01-06  0.189904  0.004523 -0.303933  0.811323

# %%
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000  1.807413  5
# 2013-01-02  0.386881 -0.290112 -0.876755  5
# 2013-01-03 -0.414971 -1.326783  0.516989  5
# 2013-01-04 -1.935550  1.020537  0.683490  5
# 2013-01-05 -1.103351 -1.162799  0.509058  5
# 2013-01-06  0.189904  0.004523 -0.303933  5

# %%
df['F'] = s1

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.807413  5  NaN
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0
# 2013-01-03 -0.414971 -1.326783  0.516989  5  2.0
# 2013-01-04 -1.935550  1.020537  0.683490  5  3.0
# 2013-01-05 -1.103351 -1.162799  0.509058  5  4.0
# 2013-01-06  0.189904  0.004523 -0.303933  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.807413 -5  NaN
# 2013-01-02 -0.386881 -0.290112 -0.876755 -5 -1.0
# 2013-01-03 -0.414971 -1.326783 -0.516989 -5 -2.0
# 2013-01-04 -1.935550 -1.020537 -0.683490 -5 -3.0
# 2013-01-05 -1.103351 -1.162799 -0.509058 -5 -4.0
# 2013-01-06 -0.189904 -0.004523 -0.303933 -5 -5.0

# %%
df1 = df.reindex(index = dates[0:4], columns = list(df.columns)+ ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.807413  5  NaN  1.0
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0  1.0
# 2013-01-03 -0.414971 -1.326783  0.516989  5  2.0  NaN
# 2013-01-04 -1.935550  1.020537  0.683490  5  3.0  NaN

# %%
df1.dropna(how = 'any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0  1.0

# %%
df1.fillna(value = 5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.807413  5  5.0  1.0
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0  1.0
# 2013-01-03 -0.414971 -1.326783  0.516989  5  2.0  5.0
# 2013-01-04 -1.935550  1.020537  0.683490  5  3.0  5.0

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.807413  5  NaN  1.0
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0  1.0
# 2013-01-03 -0.414971 -1.326783  0.516989  5  2.0  NaN
# 2013-01-04 -1.935550  1.020537  0.683490  5  3.0  NaN

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.807413  5  NaN
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0
# 2013-01-03 -0.414971 -1.326783  0.516989  5  2.0
# 2013-01-04 -1.935550  1.020537  0.683490  5  3.0
# 2013-01-05 -1.103351 -1.162799  0.509058  5  4.0
# 2013-01-06  0.189904  0.004523 -0.303933  5  5.0

# %%
df.mean()
# Out:
# A   -0.479515
# B   -0.292439
# C    0.389377
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.701853
# 2013-01-02    1.044003
# 2013-01-03    1.155047
# 2013-01-04    1.553695
# 2013-01-05    1.448581
# 2013-01-06    1.978099
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index = dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis = 'index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.414971 -2.326783 -0.483011  4.0  1.0
# 2013-01-04 -4.935550 -1.979463 -2.316510  2.0  0.0
# 2013-01-05 -6.103351 -6.162799 -4.490942  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.807413  5  NaN
# 2013-01-02  0.386881 -0.290112 -0.876755  5  1.0
# 2013-01-03 -0.414971 -1.326783  0.516989  5  2.0
# 2013-01-04 -1.935550  1.020537  0.683490  5  3.0
# 2013-01-05 -1.103351 -1.162799  0.509058  5  4.0
# 2013-01-06  0.189904  0.004523 -0.303933  5  5.0

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  1.807413   5   NaN
# 2013-01-02  0.386881 -0.290112  0.930657  10   1.0
# 2013-01-03 -0.028090 -1.616895  1.447646  15   3.0
# 2013-01-04 -1.963640 -0.596358  2.131136  20   6.0
# 2013-01-05 -3.066991 -1.759157  2.640194  25  10.0
# 2013-01-06 -2.877087 -1.754634  2.336260  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.322432
# B    2.347320
# C    2.684168
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    4
# 1    2
# 2    3
# 3    4
# 4    2
# 5    2
# 6    2
# 7    4
# 8    0
# 9    6
# dtype: int32

# %%
s.value_counts()
# Out:
# 2    4
# 4    3
# 6    1
# 3    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.622200 -0.211726 -0.779091 -0.252597
# 1  1.165217 -0.906548 -0.819760  0.276741
# 2  0.769166  1.663538  0.442271  1.244472
# 3  0.580931 -0.249794 -0.288514  0.738766
# 4 -0.205939 -1.042518 -0.462812  1.025263
# 5 -0.294882 -0.293376  1.440510 -0.106353
# 6 -0.062074  0.801066  0.078006 -0.089416
# 7  0.547032 -1.304567  0.003483  0.069153
# 8  0.040322  0.438137  0.349115  0.713725
# 9 -0.940401 -0.273914 -0.360439  1.310307

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.622200 -0.211726 -0.779091 -0.252597
#  1  1.165217 -0.906548 -0.819760  0.276741
#  2  0.769166  1.663538  0.442271  1.244472,
#            0         1         2         3
#  3  0.580931 -0.249794 -0.288514  0.738766
#  4 -0.205939 -1.042518 -0.462812  1.025263
#  5 -0.294882 -0.293376  1.440510 -0.106353
#  6 -0.062074  0.801066  0.078006 -0.089416,
#            0         1         2         3
#  7  0.547032 -1.304567  0.003483  0.069153
#  8  0.040322  0.438137  0.349115  0.713725
#  9 -0.940401 -0.273914 -0.360439  1.310307]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.622200 -0.211726 -0.779091 -0.252597
# 1  1.165217 -0.906548 -0.819760  0.276741
# 2  0.769166  1.663538  0.442271  1.244472
# 3  0.580931 -0.249794 -0.288514  0.738766
# 4 -0.205939 -1.042518 -0.462812  1.025263
# 5 -0.294882 -0.293376  1.440510 -0.106353
# 6 -0.062074  0.801066  0.078006 -0.089416
# 7  0.547032 -1.304567  0.003483  0.069153
# 8  0.040322  0.438137  0.349115  0.713725
# 9 -0.940401 -0.273914 -0.360439  1.310307

# %%
left = pd.DataFrame({'key': ['foo','foo'], 'lval': [1,2]})
right = pd.DataFrame({'key': ['foo','foo'], 'rval': [4,5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1,2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4,5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left,right,on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8,4), columns = ['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.001336  0.263065 -0.349749 -0.123774
# 1 -0.495935 -0.249982  0.819578 -0.277526
# 2 -0.566801 -1.065198  1.103469  0.745336
# 3 -1.095075 -0.529765  0.550272  0.607602
# 4  1.959674 -1.063032 -0.651979 -0.246732
# 5 -0.170402  0.625484 -0.240666  0.733294
# 6  0.183274 -1.638097 -0.204123 -0.201172
# 7 -1.119834 -0.544594  0.025257 -0.124967

# %%
s = df.iloc[3]
df.append(s,ignore_index = True)
# Out:
#           A         B         C         D
# 0  0.001336  0.263065 -0.349749 -0.123774
# 1 -0.495935 -0.249982  0.819578 -0.277526
# 2 -0.566801 -1.065198  1.103469  0.745336
# 3 -1.095075 -0.529765  0.550272  0.607602
# 4  1.959674 -1.063032 -0.651979 -0.246732
# 5 -0.170402  0.625484 -0.240666  0.733294
# 6  0.183274 -1.638097 -0.204123 -0.201172
# 7 -1.119834 -0.544594  0.025257 -0.124967
# 8 -1.095075 -0.529765  0.550272  0.607602

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                  'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                  'C': np.random.randn(8),
                  'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.214415 -0.219584
# 1  bar    one  0.875886  0.502842
# 2  foo    two  0.373848  1.350632
# 3  bar  three  0.344976 -1.061183
# 4  foo    two  0.125435 -0.684339
# 5  bar    two  0.822707 -1.750106
# 6  foo    one -1.006045  0.956490
# 7  foo  three -0.199697  0.141666

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  2.043569 -2.308448
# foo -0.920875  1.544866

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
                   ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))
# tuples
index = pd.MultiIndex.from_tuples(tuples, names = ['first','second'])
# index
df = pd.DataFrame(np.random.randn(8,2), index = index, columns = ['A','B'])
# df
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -2.305831  0.132839
#       two     0.055240 -1.102921
# baz   one     1.135159  0.422368
#       two    -0.445581 -2.408892

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -2.305831
#                B    0.132839
#        two     A    0.055240
#                B   -1.102921
# baz    one     A    1.135159
#                B    0.422368
#        two     A   -0.445581
#                B   -2.408892
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -2.305831  0.132839
#       two     0.055240 -1.102921
# baz   one     1.135159  0.422368
#       two    -0.445581 -2.408892

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -2.305831  1.135159
#        B  0.132839  0.422368
# two    A  0.055240 -0.445581
#        B -1.102921 -2.408892

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -2.305831  0.055240
#       B  0.132839 -1.102921
# baz   A  1.135159 -0.445581
#       B  0.422368 -2.408892

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                   'B': ['A', 'B', 'C'] * 4,
                   'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D': np.random.randn(12),
                   'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.619275  0.003484
# 1     one  B  foo -0.096400 -1.648054
# 2     two  C  foo  0.764342  0.786996
# 3   three  A  bar -0.274637 -0.065167
# 4     one  B  bar  0.463642 -0.232458
# 5     one  C  bar  0.943035 -0.470104
# 6     two  A  foo  1.167530 -1.380138
# 7   three  B  foo  0.393214  2.325094
# 8     one  C  foo  0.028054 -0.658014
# 9     one  A  bar  1.089287  0.264682
# 10    two  B  bar  0.183471  0.552189
# 11  three  C  bar  0.444901  0.612477

# %%
pd.pivot_table(df, values = 'D', index = ['A','B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A  1.089287 -1.619275
#       B  0.463642 -0.096400
#       C  0.943035  0.028054
# three A -0.274637       NaN
#       B       NaN  0.393214
#       C  0.444901       NaN
# two   A       NaN  1.167530
#       B  0.183471       NaN
#       C       NaN  0.764342

# %%
rng = pd.date_range('1/1/2012', periods = 100, freq = 'S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index = rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25242
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods = 5, freq = 'D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.098753
# 2012-03-07    0.378237
# 2012-03-08    1.565766
# 2012-03-09   -0.987135
# 2012-03-10    0.310553
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.098753
# 2012-03-07 00:00:00+00:00    0.378237
# 2012-03-08 00:00:00+00:00    1.565766
# 2012-03-09 00:00:00+00:00   -0.987135
# 2012-03-10 00:00:00+00:00    0.310553
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.098753
# 2012-03-06 19:00:00-05:00    0.378237
# 2012-03-07 19:00:00-05:00    1.565766
# 2012-03-08 19:00:00-05:00   -0.987135
# 2012-03-09 19:00:00-05:00    0.310553
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods = 5, freq = 'M')
ts = pd.Series(np.random.randn(len(rng)), index = rng)
ts
# Out:
# 2012-01-31    0.050759
# 2012-02-29   -0.903025
# 2012-03-31   -0.189166
# 2012-04-30   -0.567949
# 2012-05-31    0.291839
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    0.050759
# 2012-02   -0.903025
# 2012-03   -0.189166
# 2012-04   -0.567949
# 2012-05    0.291839
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.050759
# 2012-02-01   -0.903025
# 2012-03-01   -0.189166
# 2012-04-01   -0.567949
# 2012-05-01    0.291839
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1','2000Q4',freq = 'Q-NOV')
ts = pd.Series(np.random.randn(len(prng)),prng)
ts.index = (prng.asfreq('M','e')+1).asfreq('H','s') + 9
ts.head()
# Out:
# 1990-03-01 09:00   -0.780047
# 1990-06-01 09:00   -1.761834
# 1990-09-01 09:00   -0.330652
# 1990-12-01 09:00    1.174262
# 1991-03-01 09:00    0.353377
# Freq: H, dtype: float64

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                    "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df['grade'] = df['raw_grade'].astype('category')
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df['grade'].cat.categories = ['very good', 'good', 'very bad']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-6949f3611bbd> in <module>()
# ----> 1 df['grade'].cat.categories = ['very good', 'good', 'very bad']
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __setattr__(self, key, value)
#     157             raise AttributeError("You cannot add any new attribute '{key}'".
#     158                                  format(key=key))
# --> 159         object.__setattr__(self, key, value)
#     160
#     161
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in _setter(self, new_values)
#      76
#      77             def _setter(self, new_values):
# ---> 78                 return self._delegate_property_set(name, new_values)
#      79
#      80             _getter.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in _delegate_property_set(self, name, new_values)
#    2391
#    2392     def _delegate_property_set(self, name, new_values):
# -> 2393         return setattr(self.categorical, name, new_values)
#    2394
#    2395     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in categories(self, categories)
#     414         if (self.dtype.categories is not None and
#     415                 len(self.dtype.categories) != len(new_dtype.categories)):
# --> 416             raise ValueError("new categories need to have the same number of "
#     417                              "items as the old categories!")
#     418         self._dtype = new_dtype
#
# ValueError: new categories need to have the same number of items as the old categories!

# %%
df['grade'] = df['grade'].cat.set_categories(['very bad', 'bad', 'medium', 'good', 'very good']) 
df['grade']
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by = 'grade')
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby('grade').size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
ts = pd.Series(np.random.randn(1000),
              index = pd.date_range('1/1/2000', periods = 1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000,4),
                 index = ts.index, columns = ['A','B','C','D'])
df = df.cumsum()
df.plot()

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          